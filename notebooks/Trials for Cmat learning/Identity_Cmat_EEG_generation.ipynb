# %%
# !pip install neurolib
# Out:
# Requirement already satisfied: neurolib in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (0.6.2)
# Requirement already satisfied: psutil in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (5.9.4)
# Requirement already satisfied: h5py in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (3.11.0)
# Requirement already satisfied: numba in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (0.59.1)
# Requirement already satisfied: numpy in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (1.24.2)
# Requirement already satisfied: scipy in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (1.9.1)
# Requirement already satisfied: xarray in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (2024.3.0)
# Requirement already satisfied: pandas in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (2.0.0)
# Requirement already satisfied: tqdm in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (4.66.1)
# Requirement already satisfied: pypet in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (0.6.1)
# Requirement already satisfied: deap in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (1.4.1)
# Requirement already satisfied: dill in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (0.3.7)
# Requirement already satisfied: sympy in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (1.12)
# Requirement already satisfied: jitcdde in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (1.8.1)
# Requirement already satisfied: dpath in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from neurolib) (2.1.6)
# Requirement already satisfied: jitcxde-common>1.3 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from jitcdde->neurolib) (1.5.4)
# Requirement already satisfied: symengine>=0.3.1.dev0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from jitcdde->neurolib) (0.11.0)
# Requirement already satisfied: chspy>=1.1 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from jitcdde->neurolib) (1.2.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from numba->neurolib) (0.42.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from pandas->neurolib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from pandas->neurolib) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from pandas->neurolib) (2023.3)
# Requirement already satisfied: tables in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from pypet->neurolib) (3.9.2)
# Requirement already satisfied: mpmath>=0.19 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from sympy->neurolib) (1.3.0)
# Requirement already satisfied: packaging>=22 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from xarray->neurolib) (23.0)
# Requirement already satisfied: jinja2 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from jitcxde-common>1.3->jitcdde->neurolib) (3.1.2)
# Requirement already satisfied: setuptools in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from jitcxde-common>1.3->jitcdde->neurolib) (49.2.1)
# Requirement already satisfied: six>=1.5 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->neurolib) (1.16.0)
# Requirement already satisfied: numexpr>=2.6.2 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from tables->pypet->neurolib) (2.10.0)
# Requirement already satisfied: py-cpuinfo in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from tables->pypet->neurolib) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from tables->pypet->neurolib) (2.5.1)
# Requirement already satisfied: ndindex>=1.4 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from blosc2>=2.3.0->tables->pypet->neurolib) (1.8)
# Requirement already satisfied: msgpack in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from blosc2>=2.3.0->tables->pypet->neurolib) (1.0.8)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from jinja2->jitcxde-common>1.3->jitcdde->neurolib) (2.1.3)

# %%
# !pip install mne
# Out:
# Collecting mne
#   Downloading mne-1.6.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.21.2 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from mne) (1.24.2)
# Requirement already satisfied: scipy>=1.7.1 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from mne) (1.9.1)
# Requirement already satisfied: matplotlib>=3.5.0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from mne) (3.7.1)
# Requirement already satisfied: tqdm in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from mne) (4.66.1)
# Collecting pooch>=1.5 (from mne)
#   Using cached pooch-1.8.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: decorator in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from mne) (5.1.1)
# Requirement already satisfied: packaging in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from mne) (23.0)
# Requirement already satisfied: jinja2 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from mne) (3.1.2)
# Collecting lazy-loader>=0.3 (from mne)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (5.12.0)
# Requirement already satisfied: platformdirs>=2.5.0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from pooch>=1.5->mne) (3.2.0)
# Requirement already satisfied: requests>=2.19.0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from pooch>=1.5->mne) (2.28.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from jinja2->mne) (2.1.3)
# Requirement already satisfied: zipp>=3.1.0 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.0->mne) (3.15.0)
# Requirement already satisfied: six>=1.5 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in ./.pyenv/versions/3.9.2/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2022.12.7)
# Downloading mne-1.6.1-py3-none-any.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 8.0 MB/s eta 0:00:0000:0100:01
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached pooch-1.8.1-py3-none-any.whl (62 kB)
# Installing collected packages: lazy-loader, pooch, mne
#   Attempting uninstall: lazy-loader
#     Found existing installation: lazy_loader 0.2
#     Uninstalling lazy_loader-0.2:
#       Successfully uninstalled lazy_loader-0.2
# Successfully installed lazy-loader-0.4 mne-1.6.1 pooch-1.8.1

# %%
import numpy as np
import mne
from neurolib.models.model import Model

class EEGModel(Model):
    def __init__(self, params, leadfield_matrix, stimulus):
        # Define the state variable names
        self.state_vars = ["eeg_signal"]
        # Define the default output variable
        self.default_output = "eeg_signal"
        # Store the leadfield matrix
        self.leadfield_matrix = leadfield_matrix
        # Store the stimulus signal
        self.stimulus = stimulus
        # Initialize the base Model class
        super().__init__(self.integration, params)

    def integration(self, params):
        # Define the time vector
        t = np.linspace(0, params["duration"], int(params["duration"] / params["dt"]) + 1)
        # Initialize the EEG signal array
        eeg_signal = np.zeros((self.leadfield_matrix.shape[0], len(t)))

        # Simulate the EEG response to the stimulus using the leadfield matrix
        for i in range(1, len(t)):
            # Generate source activity based on the stimulus
            source_activity = np.zeros(self.leadfield_matrix.shape[1])
            if self.stimulus[i] == 1:  # Target stimulus
                source_activity[params["target_region"]] = np.sin(2 * np.pi * params["target_freq"] * t[i])
            elif self.stimulus[i] == -1:  # Non-target stimulus
                source_activity[params["non_target_region"]] = np.sin(2 * np.pi * params["non_target_freq"] * t[i])
            
            # Project the source activity to the sensor space using the leadfield matrix
            eeg_signal[:, i] = np.dot(self.leadfield_matrix, source_activity)

        return t, eeg_signal

# Example usage
params = {
    "dt": 0.01,
    "duration": 10.0,
    "target_freq": 10.0,  # Frequency of the EEG response to the target stimulus
    "non_target_freq": 5.0,  # Frequency of the EEG response to the non-target stimulus
    "target_region": 0,  # Index of the target region in the source space
    "non_target_region": 1,  # Index of the non-target region in the source space
}
leadfield_matrix = np.load('leadfield_matrix.npy')  # Load the leadfield matrix
stimulus = np.zeros(1001)  # Define your stimulus array here (e.g., square signal)

model = EEGModel(params, leadfield_matrix, stimulus)
model.run()
eeg_signal = model.output
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 47
#      38 # Example usage
#      39 params = {
#      40     "dt": 0.01,
#      41     "duration": 10.0,
#    (...)
#      45     "non_target_region": 1,  # Index of the non-target region in the source space
#      46 }
# ---> 47 leadfield_matrix = np.load('leadfield_matrix.npy')  # Load the leadfield matrix
#      48 stimulus = np.zeros(1001)  # Define your stimulus array here (e.g., square signal)
#      50 model = EEGModel(params, leadfield_matrix, stimulus)
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'leadfield_matrix.npy'

# %%
import numba
import numpy as np
from numpy.random import random as rand
from neurolib.models.model import Model
from neurolib.optimize.evolution import Evolution

class EEGModel(Model):
    state_vars = ["eeg_signal"]
    default_output = "eeg_signal"
    init_vars = ["eeg_init"]
    params = dict(tau=10, K=1e-2, dt=1e-1, duration=100, stimulus_amplitude=1.0)
    
    def __init__(self, Cmat=np.zeros((1,1)), stimulus=np.zeros(1000)):
        self.params['Cmat'] = Cmat
        self.params['stimulus'] = stimulus
        super().__init__(self.timeIntegration, self.params)
        
    def timeIntegration(self, p):
        p['N'] = p['Cmat'].shape[0]  # number of nodes
        t = np.arange(1, p['duration'] / p['dt'] + 1)  # holds time steps
        eeg_signal = np.ndarray((p['N'], len(t) + 1))  # holds variable eeg_signal
        # either use predefined initial conditions or random ones
        eeg_signal[:, :1] = p['eeg_init'] if 'eeg_init' in p else rand((p['N'], 1))
        return njit_integrate(eeg_signal, t, p['tau'], p['K'], p['N'], p['Cmat'], p['dt'], p['stimulus'], p['stimulus_amplitude'])

    @numba.njit
    def njit_integrate(eeg_signal, t, tau, K, N, Cmat, dt, stimulus, stimulus_amplitude):
        for i in range(1, 1 + len(t)):  # loop over time
            inp = Cmat.dot(eeg_signal[:, i-1]) + stimulus_amplitude * stimulus[i-1]  # input vector with stimulus
            for n in range(N):  # loop over nodes
                eeg_signal[n, i] = eeg_signal[n, i-1] + (- eeg_signal[n, i-1] / tau + K * inp[n]) * dt  # model equations
        return t, eeg_signal

    def evalFunction(individual):
        # Convert the individual to a connectivity matrix
        Cmat = np.array(individual).reshape((n_nodes, n_nodes))
        
        # Create an instance of the EEGModel with the current Cmat
        model = EEGModel(Cmat=Cmat, stimulus=square_signal)
        
        # Run the model simulation
        model.run()
        
        # Access the generated EEG signal
        simulated_eeg_signal = model.output
        
        # Calculate the fitness based on the difference between the simulated and real EEG signals
        fitness = -np.mean((simulated_eeg_signal - real_eeg_signal) ** 2)
        
        return fitness,

# Define the parameter space for the connectivity matrix
n_nodes = 10  # Number of nodes in the network
parameterSpace = ParameterSpace(['Cmat'], [[0, 1]] * (n_nodes ** 2))

# Define other parameters for the evolutionary algorithm
weightList = [-1.0]  # Minimize the fitness
POP_SIZE = 20
NGEN = 10

# Create an instance of the Evolution class
evolution = Evolution(
    evalFunction=evalFunction,
    parameterSpace=parameterSpace,
    weightList=weightList,
    POP_SIZE=POP_SIZE,
    NGEN=NGEN
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 5
#       3 from numpy.random import random as rand
#       4 from neurolib.models.model import Model
# ----> 5 from neurolib.optimize.evolution import Evolution
#       7 class EEGModel(Model):
#       8     state_vars = ["eeg_signal"]
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/neurolib/optimize/evolution/__init__.py:1
# ----> 1 from .evolution import Evolution
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/neurolib/optimize/evolution/evolution.py:10
#       8 import numpy as np
#       9 import pandas as pd
# ---> 10 import pypet as pp
#      11 from deap import base, creator, tools
#      13 from ...utils import paths as paths
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/pypet/__init__.py:13
#       7 except ImportError:
#       8     # We're running in a tree that doesn't
#       9     # have a _version.py, so we don't know what our version is.
#      10     __version__ = "unknown"
# ---> 13 from pypet.environment import Environment, MultiprocContext
#      14 from pypet.trajectory import Trajectory, load_trajectory
#      15 from pypet.storageservice import HDF5StorageService, LazyStorageService
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/pypet/environment.py:68
#      65 except ImportError:
#      66     zmq = None
# ---> 68 from pypet.pypetlogging import LoggingManager, HasLogger, simple_logging_config
#      69 from pypet.trajectory import Trajectory
#      70 from pypet.storageservice import HDF5StorageService, LazyStorageService
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/pypet/pypetlogging.py:27
#      24 import functools
#      25 import socket
# ---> 27 import pypet.pypetconstants as pypetconstants
#      28 from pypet.utils.helpful_functions import progressbar, racedirs
#      29 from pypet.utils.decorators import retry
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/pypet/pypetconstants.py:15
#      13 ####################### VERSIONS_TO_STORE ####################
#      14 from pypet._version import __version__ as VERSION
# ---> 15 import tables
#      16 tablesversion = tables.__version__
#      17 hdf5version = tables.hdf5_version
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/tables/__init__.py:44
#      40     raise RuntimeError("Blosc2 library not found. "
#      41                        f"I looked for \"{', '.join(blosc2_search_paths)}\"")
#      43 # Necessary imports to get versions stored on the cython extension
# ---> 44 from .utilsextension import get_hdf5_version as _get_hdf5_version
#      46 from ._version import __version__
#      48 hdf5_version = _get_hdf5_version()
#
# ImportError: dlopen(/Users/aliag/.pyenv/versions/3.9.2/lib/python3.9/site-packages/tables/utilsextension.cpython-39-darwin.so, 0x0002): symbol not found in flat namespace '_H5Lget_info'

# %%
import matplotlib.pyplot as plt

# Define the connectivity matrix (for simplicity, we'll use a 2x2 identity matrix)
Cmat = np.eye(2)

# Define the square wave stimulus
duration = 1000  # duration in time steps
stimulus = np.zeros(duration)
stimulus[100:200] = 1  # a square pulse between timesteps 100 and 200
stimulus[400:500] = 1  # another square pulse between timesteps 400 and 500

# Create an instance of the EEGModel
model = EEGModel(Cmat=Cmat, stimulus=stimulus)

# Run the model simulation
model.run()

# Access the generated EEG signal
eeg_signal = model.output

# Plot the EEG signal
plt.figure(figsize=(10, 5))
plt.plot(eeg_signal[0], label='EEG signal at node 1')
plt.plot(eeg_signal[1], label='EEG signal at node 2')
plt.plot(stimulus * 0.5, label='Stimulus (scaled for visualization)', linestyle='--')
plt.xlabel('Time step')
plt.ylabel('Signal amplitude')
plt.legend()
plt.title('Simulated EEG signal with square wave stimulus')
plt.show()
# Out:
# /var/folders/by/2njwfm9x7sbdz_xdq73474s00000gn/T/ipykernel_47559/184100909.py:28: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   inp = Cmat.dot(eeg_signal[:, i-1]) + stimulus_amplitude * stimulus[i-1]  # input vector with stimulus
